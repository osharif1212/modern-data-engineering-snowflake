# %%
from snowflake.snowpark.session import Session
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from snowflake.snowpark.session import Session
#
# ModuleNotFoundError: No module named 'snowflake'
